# %%
import os
import soundfile as sf
import librosa
import numpy as np
import ntpath
import matplotlib.pyplot as plt
# from librosa import display
import librosa.display

import sys
import pandas as pd
import matplotlib
import json

# %%
with open('fileLocations.json') as json_file:
    data = json.load(json_file)

path = os.getcwd() + "/datasets/" 

audios = []

currentFolder = "/Assorted Channels/"

for file in data["Assorted Channels"]:
    audios.append(file)
    

    
fig = plt.figure(figsize=[15, 15])
numRowsX = 4
numRowsY = 8
ax = []
for i in range(numRowsX):
    for j in range(numRowsY):
        ax.append(plt.subplot2grid((numRowsY, numRowsX), (j, i)))
        
    
for i in range(numRowsX*numRowsY):
    times = np.arange(100)
    values = np.random.randn(len(times))
    y, sr = librosa.load(path+currentFolder + audios[i])
    img = librosa.display.waveshow(y, sr=sr, ax=ax[i])
    ax[i].set(title = "File: " + audios[i])
    ax[i].label_outer()
    ax[i].xaxis.set_major_formatter(librosa.display.TimeFormatter(unit='ms'))
    ax[i].set(xlabel='Time (ms)')
# Out:
# c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\core\audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     163 try:
# --> 164     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166 except RuntimeError as exc:
#     167     # If soundfile failed, try audioread instead
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\core\audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     193 else:
#     194     # Otherwise, create the soundfile object
# --> 195     context = sf.SoundFile(path)
#     197 with context as sf_desc:
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\soundfile.py:629, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     627 self._info = _create_info_struct(file, mode, samplerate, channels,
#     628                                  format, subtype, endian)
# --> 629 self._file = self._open(file, mode_int, closefd)
#     630 if set(mode).issuperset('r+') and self.seekable():
#     631     # Move write position to 0 (like in Python file objects)
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\soundfile.py:1183, in SoundFile._open(self, file, mode_int, closefd)
#    1182     raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183 _error_check(_snd.sf_error(file_ptr),
#    1184              "Error opening {0!r}: ".format(self.name))
#    1185 if mode_int == _snd.SFM_WRITE:
#    1186     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1187     # when opening a named pipe in SFM_WRITE mode.
#    1188     # See http://github.com/erikd/libsndfile/issues/77.
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\soundfile.py:1357, in _error_check(err, prefix)
#    1356 err_str = _snd.sf_error_number(err)
# -> 1357 raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#
# RuntimeError: Error opening 'E:\\anaki\\Documents\\Coding\\Keybird-Hackathon/datasets//Assorted Channels/7V but sounds like Jelly Epoch - Typing Test.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 24>()
#      25 times = np.arange(100)
#      26 values = np.random.randn(len(times))
# ---> 27 y, sr = librosa.load(path+currentFolder + audios[i])
#      28 img = librosa.display.waveshow(y, sr=sr, ax=ax[i])
#      29 ax[i].set(title = "File: " + audios[i])
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\core\audio.py:170, in load(path, sr, mono, offset, duration, dtype, res_type)
#     168 if isinstance(path, (str, pathlib.PurePath)):
#     169     warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> 170     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     171 else:
#     172     raise exc
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\librosa\core\audio.py:226, in __audioread_load(path, offset, duration, dtype)
#     223     reader = path
#     224 else:
#     225     # If the input was not an audioread object, try to open it
# --> 226     reader = audioread.audio_open(path)
#     228 with reader as input_file:
#     229     sr_native = input_file.samplerate
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\audioread\__init__.py:111, in audio_open(path, backends)
#     109 for BackendClass in backends:
#     110     try:
# --> 111         return BackendClass(path)
#     112     except DecodeError:
#     113         pass
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\audioread\rawread.py:62, in RawAudioFile.__init__(self, filename)
#      61 def __init__(self, filename):
# ---> 62     self._fh = open(filename, 'rb')
#      64     try:
#      65         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\anaki\\Documents\\Coding\\Keybird-Hackathon/datasets//Assorted Channels/7V but sounds like Jelly Epoch - Typing Test.wav'

# %%
csvs = {}
for outerFolder in os.listdir(os.getcwd() + "/datasets/"):
    tempList = []
    for file in os.listdir(os.getcwd() + "/datasets/"+ outerFolder):
        tempList.append(file)
    csvs[outerFolder] = tempList
with open('fileLocations.json', 'w') as outfile:
    json.dump(csvs, outfile)

# %%
with open('fileLocations.json') as json_file:
    data = json.load(json_file)
# Out:
# dict_keys(['Assorted Channels', 'filled types', 'Typing Sounds Wav'])
