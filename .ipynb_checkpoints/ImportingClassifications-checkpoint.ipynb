# %%
import os
import numpy as np
from tqdm import tqdm
import pandas as pd
import soundfile as sf

path = os.getcwd()
audios = []
typingSounds = path + "/data/reprocessed_Assorted Channels/samples_from_onsets/7V but sounds like Jelly Epoch - Typing Test/"
total = len(os.listdir(typingSounds))
pbar = tqdm(total = total)
temp = 0
for file in os.listdir(typingSounds):
    data, sr = sf.read(typingSounds + file)
    audios.append(data)
    pbar.update(1)
pbar.close()
dataset = pd.DataFrame.from_dict(audios)
#samDict = pd.read_csv("samClassify.csv", nrows=29)
#steDict = pd.read_csv("stevenClassify.csv", nrows=49)

#dataset = pd.DataFrame.from_dict(samDict)
print(dataset)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 406/406 [00:00<00:00, 3660.94it/s]
#          0         1         2         3         4         5         6     \
# 0   -0.006235 -0.008036 -0.004966 -0.001479 -0.000534 -0.001306 -0.002461
# 1   -0.000896 -0.000339 -0.002164 -0.004230 -0.005978 -0.005916 -0.003984
# 2    0.006242  0.006265  0.004665  0.001822 -0.000175  0.000335  0.001868
# 3    0.005131  0.006397  0.007469  0.006333  0.003806  0.000440 -0.003247
# 4   -0.000597  0.000903  0.005069  0.009372  0.011944  0.011639  0.008792
# ..        ...       ...       ...       ...       ...       ...       ...
# 401  0.007534  0.009736  0.006662  0.001152 -0.007211 -0.011846 -0.009259
# 402 -0.009239 -0.011181 -0.014850 -0.014089 -0.010715 -0.008439 -0.006324
# 403  0.003650  0.003930  0.003201  0.002059  0.001275  0.001675  0.002558
# 404  0.002728  0.008223  0.013885  0.017215  0.017117  0.014163  0.011380
# 405  0.003633  0.003496  0.003806  0.004590  0.005208  0.005613  0.006493
#
#          7         8         9     ...      4086      4087      4088  \
# 0   -0.004626 -0.006929 -0.007501  ... -0.003515 -0.006745 -0.008391
# 1   -0.002034 -0.001251 -0.000987  ... -0.003941 -0.006736 -0.008401
# 2    0.003146  0.003532  0.002995  ... -0.004067 -0.005728 -0.005187
# 3   -0.004974 -0.004840 -0.002084  ... -0.000242 -0.000104 -0.001814
# 4    0.004620  0.001250 -0.000312  ...  0.001638  0.001342  0.002064
# ..        ...       ...       ...  ...       ...       ...       ...
# 401 -0.002152  0.005711  0.008751  ...  0.018202  0.000160 -0.011105
# 402 -0.004763 -0.004080 -0.004351  ...  0.006783  0.005578  0.003431
# 403  0.002674  0.001464 -0.000196  ... -0.003117 -0.003216 -0.003866
# 404  0.008845  0.004643  0.001806  ... -0.000425 -0.000152  0.000318
# 405  0.007779  0.008125  0.007226  ... -0.003903 -0.002616 -0.001651
#
#          4089      4090      4091      4092      4093      4094      4095
# 0   -0.006107 -0.002909 -0.000080  0.002178  0.002114  0.000172 -0.004072
# 1   -0.007916 -0.005829 -0.001582  0.002630  0.004181  0.004085  0.003435
# 2   -0.002844 -0.000442  0.000096 -0.001181 -0.003050 -0.005423 -0.005908
# 3   -0.003393 -0.005396 -0.007369 -0.007900 -0.006815 -0.005410 -0.003286
# 4   -0.000965 -0.006730 -0.001952  0.024986  0.064092  0.094876  0.102476
# ..        ...       ...       ...       ...       ...       ...       ...
# 401 -0.022032 -0.011787  0.006294  0.025214  0.028779  0.013173 -0.004888
# 402  0.001856  0.001155  0.001302  0.001812  0.000555 -0.000989 -0.001961
# 403 -0.003703 -0.002724 -0.003407 -0.004489 -0.004979 -0.004290 -0.003989
# 404 -0.000102 -0.001300 -0.001987 -0.001209 -0.000985 -0.000367  0.000393
# 405 -0.001565 -0.002543 -0.003002 -0.002699 -0.001582 -0.000169  0.000557
#
# [406 rows x 4096 columns]
