# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_static_60_5.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, 'unknown')
    #print(model.predict(X_to_predict))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 20, 11, 32)        320
#
#  max_pooling2d_18 (MaxPoolin  (None, 10, 6, 32)        0
#  g2D)
#
#  batch_normalization_18 (Bat  (None, 10, 6, 32)        128
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 8, 4, 32)          9248
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 2, 32)         0
#  g2D)
#
#  batch_normalization_19 (Bat  (None, 4, 2, 32)         128
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 3, 1, 32)          4128
#
#  max_pooling2d_20 (MaxPoolin  (None, 2, 1, 32)         0
#  g2D)
#
#  batch_normalization_20 (Bat  (None, 2, 1, 32)         128
#  chNormalization)
#
#  flatten_6 (Flatten)         (None, 64)                0
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 18,890
# Trainable params: 18,698
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/50
# 44/44 [==============================] - 1s 12ms/step - loss: 2.8801 - accuracy: 0.0742 - val_loss: 2.4559 - val_accuracy: 0.1225
# Epoch 2/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.4123 - accuracy: 0.1606 - val_loss: 2.1173 - val_accuracy: 0.3105
# Epoch 3/50
# 44/44 [==============================] - 0s 6ms/step - loss: 2.0649 - accuracy: 0.2698 - val_loss: 1.8769 - val_accuracy: 0.4387
# Epoch 4/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.7623 - accuracy: 0.4069 - val_loss: 1.6587 - val_accuracy: 0.5385
# Epoch 5/50
# 44/44 [==============================] - 0s 7ms/step - loss: 1.5108 - accuracy: 0.5189 - val_loss: 1.4373 - val_accuracy: 0.5897
# Epoch 6/50
# 44/44 [==============================] - 0s 7ms/step - loss: 1.3756 - accuracy: 0.5824 - val_loss: 1.2509 - val_accuracy: 0.6610
# Epoch 7/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.2551 - accuracy: 0.6039 - val_loss: 1.1096 - val_accuracy: 0.6895
# Epoch 8/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.1007 - accuracy: 0.6667 - val_loss: 0.9889 - val_accuracy: 0.7208
# Epoch 9/50
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0361 - accuracy: 0.6688 - val_loss: 0.9051 - val_accuracy: 0.7236
# Epoch 10/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.9589 - accuracy: 0.6888 - val_loss: 0.8124 - val_accuracy: 0.7578
# Epoch 11/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8897 - accuracy: 0.7188 - val_loss: 0.7561 - val_accuracy: 0.7664
# Epoch 12/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8637 - accuracy: 0.7380 - val_loss: 0.7143 - val_accuracy: 0.7692
# Epoch 13/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8174 - accuracy: 0.7352 - val_loss: 0.6818 - val_accuracy: 0.7721
# Epoch 14/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.7404 - accuracy: 0.7666 - val_loss: 0.6467 - val_accuracy: 0.7892
# Epoch 15/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.7221 - accuracy: 0.7595 - val_loss: 0.6287 - val_accuracy: 0.7949
# Epoch 16/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6759 - accuracy: 0.7759 - val_loss: 0.5963 - val_accuracy: 0.7977
# Epoch 17/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6561 - accuracy: 0.7780 - val_loss: 0.5694 - val_accuracy: 0.8063
# Epoch 18/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6227 - accuracy: 0.7980 - val_loss: 0.5496 - val_accuracy: 0.8006
# Epoch 19/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.6032 - accuracy: 0.8094 - val_loss: 0.5345 - val_accuracy: 0.8148
# Epoch 20/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.5719 - accuracy: 0.8208 - val_loss: 0.5171 - val_accuracy: 0.8205
# Epoch 21/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.5689 - accuracy: 0.8180 - val_loss: 0.5094 - val_accuracy: 0.8291
# Epoch 22/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.5523 - accuracy: 0.8158 - val_loss: 0.4914 - val_accuracy: 0.8348
# Epoch 23/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.5129 - accuracy: 0.8308 - val_loss: 0.4824 - val_accuracy: 0.8291
# Epoch 24/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.4997 - accuracy: 0.8337 - val_loss: 0.4676 - val_accuracy: 0.8262
# Epoch 25/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.4810 - accuracy: 0.8437 - val_loss: 0.4546 - val_accuracy: 0.8376
# Epoch 26/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.4746 - accuracy: 0.8415 - val_loss: 0.4494 - val_accuracy: 0.8462
# Epoch 27/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.4286 - accuracy: 0.8558 - val_loss: 0.4380 - val_accuracy: 0.8547
# Epoch 28/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.4335 - accuracy: 0.8601 - val_loss: 0.4270 - val_accuracy: 0.8348
# Epoch 29/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.4156 - accuracy: 0.8594 - val_loss: 0.4134 - val_accuracy: 0.8405
# Epoch 30/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3996 - accuracy: 0.8565 - val_loss: 0.4143 - val_accuracy: 0.8433
# Epoch 31/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.4015 - accuracy: 0.8694 - val_loss: 0.4017 - val_accuracy: 0.8433
# Epoch 32/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3729 - accuracy: 0.8801 - val_loss: 0.4093 - val_accuracy: 0.8661
# Epoch 33/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3463 - accuracy: 0.8887 - val_loss: 0.3877 - val_accuracy: 0.8462
# Epoch 34/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3541 - accuracy: 0.8744 - val_loss: 0.3830 - val_accuracy: 0.8604
# Epoch 35/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3537 - accuracy: 0.8844 - val_loss: 0.3850 - val_accuracy: 0.8604
# Epoch 36/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3305 - accuracy: 0.8894 - val_loss: 0.3708 - val_accuracy: 0.8604
# Epoch 37/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3056 - accuracy: 0.8994 - val_loss: 0.3741 - val_accuracy: 0.8490
# Epoch 38/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3279 - accuracy: 0.8951 - val_loss: 0.3587 - val_accuracy: 0.8575
# Epoch 39/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2988 - accuracy: 0.8936 - val_loss: 0.3728 - val_accuracy: 0.8661
# Epoch 40/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3223 - accuracy: 0.8901 - val_loss: 0.3387 - val_accuracy: 0.8604
# Epoch 41/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2845 - accuracy: 0.9094 - val_loss: 0.3340 - val_accuracy: 0.8689
# Epoch 42/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.2945 - accuracy: 0.8986 - val_loss: 0.3329 - val_accuracy: 0.8775
# Epoch 43/50
# 44/44 [==============================] - 0s 8ms/step - loss: 0.2722 - accuracy: 0.9136 - val_loss: 0.3353 - val_accuracy: 0.8718
# Epoch 44/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.2892 - accuracy: 0.8986 - val_loss: 0.3212 - val_accuracy: 0.8746
# Epoch 45/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2627 - accuracy: 0.9129 - val_loss: 0.3268 - val_accuracy: 0.8632
# Epoch 46/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2491 - accuracy: 0.9186 - val_loss: 0.3280 - val_accuracy: 0.8775
# Epoch 47/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2478 - accuracy: 0.9179 - val_loss: 0.3142 - val_accuracy: 0.8746
# Epoch 48/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2484 - accuracy: 0.9136 - val_loss: 0.3199 - val_accuracy: 0.8689
# Epoch 49/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.2404 - accuracy: 0.9215 - val_loss: 0.3144 - val_accuracy: 0.8746
# Epoch 50/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.2336 - accuracy: 0.9229 - val_loss: 0.3161 - val_accuracy: 0.8689
# 19/19 - 0s - loss: 0.2986 - accuracy: 0.8716 - 67ms/epoch - 4ms/step
#
# Test accuracy: 0.8715753555297852
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 132>()
#     161 y_to_predict = y_test[100]
#     163 # predict sample
#     164 #predict(model, X_to_predict, y_to_predict)
# --> 165 print(model.predict(X_to_predict))
#
# File c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filezzvnwot8.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py", line 1845, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py", line 1834, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py", line 1823, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py", line 1791, in predict_step
#         return self(x, training=False)
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\users\anaki\appdata\local\programs\python\python39\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_6" is incompatible with the layer: expected shape=(None, 22, 13, 1), found shape=(None, 13, 1)

# %%
print(X_test.shape)
# Out:
# (584, 22, 13, 1)
