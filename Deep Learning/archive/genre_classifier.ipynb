# %% [markdown]
# ## FUTURE CHANGES
# * Remove test_train_split because this needs to be done before segmenting the datasets

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf

tf.debugging.set_log_device_placement(True)

DATASET_PATH = "data_static_60_5.json"

# load data
def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
    
    # convert lists into numpy arrays
    inputs = np.array(data["mfcc"])
    targets = np.array(data["labels"])
    #print(inputs[:1])
    
    return inputs, targets

if __name__ == "__main__":
   
    # load data
    inputs, targets = load_data(DATASET_PATH)
    print(inputs.shape)
    print(targets.shape)
    
    # split the data into train and test sets
    inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs, targets, test_size=0.3)  # 30% used for test set, rest for train set
                                                  
    # build the network architecture
    model = keras.Sequential([
        # input layer
        keras.layers.Flatten(input_shape=(inputs.shape[1], inputs.shape[2])), 
            # take multidimensional array and flattens it out
            # remember that each track has many MFCC vectors at each hop length
            # first dimension is the interval, # second dimension is the amount of MFCCs
            # note: inputs is 3D array and [0] is the different segments, so we ignore
        
        # 1st hidden layer
        keras.layers.Dense(512, activation="relu"),
        
        # 2nd hidden layer
        keras.layers.Dense(256, activation="relu"),
        
        # 3rd hidden layer
        keras.layers.Dense(64, activation="relu"),
        
        # output layer 
        # 5 neurons because predicting 5 categories clacky ,....
        keras.layers.Dense(5, activation="softmax")
    ])
    
    # compile network
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss="sparse_categorical_crossentropy",
                 metrics=['accuracy'])
    
    model.summary()
    
    # train network
    model.fit(inputs_train, 
              targets_train, 
              validation_data=(inputs_test, targets_test),
              epochs=50,
              batch_size=32) # important! # of samples in each of our batches
# Out:
# (2336, 22, 13)
# (2336,)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_11 (Flatten)         (None, 286)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               146944
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_42 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 295,045
# Trainable params: 295,045
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 52/52 [==============================] - 1s 9ms/step - loss: 18.7566 - accuracy: 0.4979 - val_loss: 5.1562 - val_accuracy: 0.6148
# Epoch 2/50
# 52/52 [==============================] - 0s 5ms/step - loss: 3.1472 - accuracy: 0.6312 - val_loss: 2.9493 - val_accuracy: 0.6006
# Epoch 3/50
# 52/52 [==============================] - 0s 7ms/step - loss: 1.9002 - accuracy: 0.6703 - val_loss: 1.8563 - val_accuracy: 0.6719
# Epoch 4/50
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5058 - accuracy: 0.7052 - val_loss: 2.1737 - val_accuracy: 0.7175
# Epoch 5/50
# 52/52 [==============================] - 0s 5ms/step - loss: 1.0558 - accuracy: 0.7731 - val_loss: 1.4859 - val_accuracy: 0.7261
# Epoch 6/50
# 52/52 [==============================] - 0s 4ms/step - loss: 1.0229 - accuracy: 0.7670 - val_loss: 1.6878 - val_accuracy: 0.6847
# Epoch 7/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7875 - accuracy: 0.7927 - val_loss: 1.6819 - val_accuracy: 0.7489
# Epoch 8/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.8657 - accuracy: 0.7994 - val_loss: 1.9033 - val_accuracy: 0.7133
# Epoch 9/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6986 - accuracy: 0.8257 - val_loss: 1.3691 - val_accuracy: 0.7447
# Epoch 10/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6501 - accuracy: 0.8398 - val_loss: 1.5873 - val_accuracy: 0.7090
# Epoch 11/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.9543 - accuracy: 0.8220 - val_loss: 1.8371 - val_accuracy: 0.6961
# Epoch 12/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7597 - accuracy: 0.8367 - val_loss: 1.2242 - val_accuracy: 0.7646
# Epoch 13/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4282 - accuracy: 0.8758 - val_loss: 1.2790 - val_accuracy: 0.7718
# Epoch 14/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.8893 - val_loss: 1.3476 - val_accuracy: 0.7732
# Epoch 15/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4598 - accuracy: 0.9021 - val_loss: 1.8582 - val_accuracy: 0.7190
# Epoch 16/50
# 52/52 [==============================] - 0s 5ms/step - loss: 1.7719 - accuracy: 0.7920 - val_loss: 1.2228 - val_accuracy: 0.7917
# Epoch 17/50
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4939 - accuracy: 0.8734 - val_loss: 1.5892 - val_accuracy: 0.7846
# Epoch 18/50
# 52/52 [==============================] - 0s 8ms/step - loss: 0.5050 - accuracy: 0.8954 - val_loss: 1.0473 - val_accuracy: 0.8131
# Epoch 19/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3102 - accuracy: 0.9235 - val_loss: 1.0277 - val_accuracy: 0.7960
# Epoch 20/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.2441 - accuracy: 0.9382 - val_loss: 1.2807 - val_accuracy: 0.7746
# Epoch 21/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3362 - accuracy: 0.9291 - val_loss: 1.1704 - val_accuracy: 0.8088
# Epoch 22/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2883 - accuracy: 0.9327 - val_loss: 1.0125 - val_accuracy: 0.8203
# Epoch 23/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2989 - accuracy: 0.9278 - val_loss: 0.9937 - val_accuracy: 0.8217
# Epoch 24/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2968 - accuracy: 0.9278 - val_loss: 0.8985 - val_accuracy: 0.8331
# Epoch 25/50
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2834 - accuracy: 0.9352 - val_loss: 1.2366 - val_accuracy: 0.7746
# Epoch 26/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.4506 - accuracy: 0.9064 - val_loss: 1.1903 - val_accuracy: 0.8074
# Epoch 27/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.9511 - accuracy: 0.8826 - val_loss: 1.0870 - val_accuracy: 0.7989
# Epoch 28/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.4149 - accuracy: 0.9119 - val_loss: 0.9415 - val_accuracy: 0.8431
# Epoch 29/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.9486 - val_loss: 1.0784 - val_accuracy: 0.7932
# Epoch 30/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3220 - accuracy: 0.9309 - val_loss: 1.4948 - val_accuracy: 0.7974
# Epoch 31/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3198 - accuracy: 0.9437 - val_loss: 1.0240 - val_accuracy: 0.8188
# Epoch 32/50
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2407 - accuracy: 0.9425 - val_loss: 1.1252 - val_accuracy: 0.8231
# Epoch 33/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1908 - accuracy: 0.9621 - val_loss: 1.5826 - val_accuracy: 0.8117
# Epoch 34/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2678 - accuracy: 0.9541 - val_loss: 0.9008 - val_accuracy: 0.8402
# Epoch 35/50
# 52/52 [==============================] - 0s 6ms/step - loss: 0.2168 - accuracy: 0.9596 - val_loss: 0.8907 - val_accuracy: 0.8459
# Epoch 36/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2159 - accuracy: 0.9602 - val_loss: 0.9879 - val_accuracy: 0.8474
# Epoch 37/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.9535 - val_loss: 1.1254 - val_accuracy: 0.8160
# Epoch 38/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9523 - val_loss: 0.8589 - val_accuracy: 0.8488
# Epoch 39/50
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1188 - accuracy: 0.9694 - val_loss: 0.9186 - val_accuracy: 0.8516
# Epoch 40/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2945 - accuracy: 0.9572 - val_loss: 1.0773 - val_accuracy: 0.8331
# Epoch 41/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4453 - accuracy: 0.9260 - val_loss: 1.4367 - val_accuracy: 0.8231
# Epoch 42/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6619 - accuracy: 0.9034 - val_loss: 1.2269 - val_accuracy: 0.7960
# Epoch 43/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.4078 - accuracy: 0.9131 - val_loss: 1.3495 - val_accuracy: 0.8103
# Epoch 44/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2092 - accuracy: 0.9621 - val_loss: 1.0517 - val_accuracy: 0.8288
# Epoch 45/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.9627 - val_loss: 1.0708 - val_accuracy: 0.8288
# Epoch 46/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2705 - accuracy: 0.9511 - val_loss: 1.1369 - val_accuracy: 0.8459
# Epoch 47/50
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3915 - accuracy: 0.9450 - val_loss: 1.2011 - val_accuracy: 0.8302
# Epoch 48/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.9560 - val_loss: 1.3436 - val_accuracy: 0.8374
# Epoch 49/50
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3671 - accuracy: 0.9450 - val_loss: 1.4669 - val_accuracy: 0.8117
# Epoch 50/50
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.9505 - val_loss: 1.5400 - val_accuracy: 0.8203
