# %%
import numpy as np
from random import random
import tensorflow as tf
from sklearn.model_selection import train_test_split

def generate_dataset(num_samples, test_size):
    x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
    y = np.array([[i[0] + i[1]] for i in x])
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
    return x_train, x_test, y_train, y_test

if __name__ == "__main__":
    x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)
    print("x_test: \n {}".format(x_test))
    print("y_test: \n {}".format(y_test))

    # build model
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    # compile model
    optimiser = tf.keras.optimizers.SGD(learning_rate=0.1)
    model.compile(optimiser="optimiser", loss="MSE")
    
    # train model
    model.fit(x_train, y_train, epochs=100)
    
    # evaluate model
    print("\nModel evaluation")
    model.evaluate(x_test, y_test, verbose=1)
    
    # make predictions
    data = np.array([[0.1, 0.2], [0.2, 0.2]])
    predictions = model.predict(data)
    
    print("\nSome predictions:")
    for d, p in zip(data, predictions):
        print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# x_test:
#  [[0.36825724 0.17406285]
#  [0.48801017 0.43785226]
#  [0.16370351 0.34195454]
#  ...
#  [0.28447652 0.19926761]
#  [0.13258414 0.12947568]
#  [0.04013167 0.17937426]]
# y_test:
#  [[0.54232009]
#  [0.92586242]
#  [0.50565805]
#  ...
#  [0.48374413]
#  [0.26205982]
#  [0.21950593]]
# Train on 3500 samples
# Epoch 1/100
# 3500/3500 [==============================] - 0s 122us/sample - loss: 0.0433
# Epoch 2/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 0.0380
# Epoch 3/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 0.0365
# Epoch 4/100
# 3500/3500 [==============================] - 0s 34us/sample - loss: 0.0349
# Epoch 5/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 0.0332
# Epoch 6/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 0.0313
# Epoch 7/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 0.0292
# Epoch 8/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 0.0270
# Epoch 9/100
# 3500/3500 [==============================] - 0s 34us/sample - loss: 0.0246
# Epoch 10/100
# 3500/3500 [==============================] - 0s 32us/sample - loss: 0.0222
# Epoch 11/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 0.0198
# Epoch 12/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 0.0173
# Epoch 13/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 0.0149
# Epoch 14/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 0.0124
# Epoch 15/100
# 3500/3500 [==============================] - 0s 32us/sample - loss: 0.0101
# Epoch 16/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 0.0079
# Epoch 17/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 0.0060
# Epoch 18/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 0.0043
# Epoch 19/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 0.0029
# Epoch 20/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 0.0018
# Epoch 21/100
# 3500/3500 [==============================] - 0s 35us/sample - loss: 0.0011
# Epoch 22/100
# 3500/3500 [==============================] - 0s 35us/sample - loss: 6.9008e-04
# Epoch 23/100
# 3500/3500 [==============================] - 0s 35us/sample - loss: 5.3307e-04
# Epoch 24/100
# 3500/3500 [==============================] - 0s 35us/sample - loss: 4.9204e-04
# Epoch 25/100
# 3500/3500 [==============================] - 0s 35us/sample - loss: 4.7970e-04
# Epoch 26/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.7308e-04
# Epoch 27/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.6772e-04
# Epoch 28/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 4.6235e-04
# Epoch 29/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.5638e-04
# Epoch 30/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.5167e-04
# Epoch 31/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.4771e-04
# Epoch 32/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.4373e-04
# Epoch 33/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 4.4001e-04
# Epoch 34/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 4.3573e-04
# Epoch 35/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 4.3144e-04
# Epoch 36/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 4.2783e-04
# Epoch 37/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 4.2408e-04
# Epoch 38/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 4.2079e-04
# Epoch 39/100
# 3500/3500 [==============================] - 0s 37us/sample - loss: 4.1781e-04
# Epoch 40/100
# 3500/3500 [==============================] - 0s 34us/sample - loss: 4.1486e-04
# Epoch 41/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 4.1270e-04
# Epoch 42/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 4.1049e-04
# Epoch 43/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 4.0769e-04
# Epoch 44/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 4.0542e-04
# Epoch 45/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 4.0279e-04
# Epoch 46/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 4.0034e-04
# Epoch 47/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.9919e-04
# Epoch 48/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.9708e-04
# Epoch 49/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 3.9577e-04
# Epoch 50/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.9366e-04
# Epoch 51/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 3.9209e-04
# Epoch 52/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 3.9045e-04
# Epoch 53/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.8904e-04
# Epoch 54/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.8749e-04
# Epoch 55/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.8538e-04
# Epoch 56/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 3.8395e-04
# Epoch 57/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.8273e-04
# Epoch 58/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.8129e-04
# Epoch 59/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 3.7913e-04
# Epoch 60/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.7909e-04
# Epoch 61/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.7794e-04
# Epoch 62/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.7582e-04
# Epoch 63/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.7534e-04
# Epoch 64/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.7504e-04
# Epoch 65/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.7333e-04
# Epoch 66/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.7255e-04
# Epoch 67/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 3.7162e-04
# Epoch 68/100
# 3500/3500 [==============================] - 0s 32us/sample - loss: 3.7031e-04
# Epoch 69/100
# 3500/3500 [==============================] - 0s 31us/sample - loss: 3.6863e-04
# Epoch 70/100
# 3500/3500 [==============================] - 0s 29us/sample - loss: 3.6883e-04
# Epoch 71/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 3.6755e-04
# Epoch 72/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.6694e-04
# Epoch 73/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.6554e-04
# Epoch 74/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.6517e-04
# Epoch 75/100
# 3500/3500 [==============================] - 0s 34us/sample - loss: 3.6509e-04
# Epoch 76/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 3.6391e-04
# Epoch 77/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 3.6374e-04
# Epoch 78/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.6234e-04
# Epoch 79/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.6161e-04
# Epoch 80/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.6154e-04
# Epoch 81/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 3.6073e-04
# Epoch 82/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.6041e-04
# Epoch 83/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5974e-04
# Epoch 84/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.5935e-04
# Epoch 85/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.5733e-04
# Epoch 86/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.5830e-04
# Epoch 87/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5698e-04
# Epoch 88/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.5620e-04
# Epoch 89/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 3.5675e-04
# Epoch 90/100
# 3500/3500 [==============================] - 0s 33us/sample - loss: 3.5586e-04
# Epoch 91/100
# 3500/3500 [==============================] - 0s 27us/sample - loss: 3.5506e-04
# Epoch 92/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.5430e-04
# Epoch 93/100
# 3500/3500 [==============================] - 0s 30us/sample - loss: 3.5376e-04
# Epoch 94/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5380e-04
# Epoch 95/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5288e-04
# Epoch 96/100
# 3500/3500 [==============================] - 0s 26us/sample - loss: 3.5328e-04
# Epoch 97/100
# 3500/3500 [==============================] - 0s 28us/sample - loss: 3.5191e-04
# Epoch 98/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5227e-04
# Epoch 99/100
# 3500/3500 [==============================] - 0s 45us/sample - loss: 3.5131e-04
# Epoch 100/100
# 3500/3500 [==============================] - 0s 25us/sample - loss: 3.5067e-04
#
# Model evaluation
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
#
# Some predictions:
# 0.1 + 0.2 = 0.28539544343948364
# 0.2 + 0.2 = 0.3877449929714203
